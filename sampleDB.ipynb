# %%
# %sql
use catalog sur_pro;
create table if not exists default.cust12
(
  id int,
  name string,
  email string
)
using csv
location 'abfss://bronze@suraj0adls.dfs.core.windows.net/cust12'

# %%
# %sql
INSERT INTO sur_pro.default.cust12 (id, name, email) VALUES
  (1, 'Alice Smith', 'alice.smith@example.com'),
  (2, 'Bob Johnson', 'bob.johnson@example.com'),
  (3, 'Carol Lee', 'carol.lee@example.com'),
  (4, 'David Kim', 'david.kim@example.com'),
  (5, 'Eva Brown', 'eva.brown@example.com'),
  (6, 'Frank White', 'frank.white@example.com'),
  (7, 'Grace Green', 'grace.green@example.com'),
  (8, 'Henry Black', 'henry.black@example.com'),
  (9, 'Ivy Young', 'ivy.young@example.com'),
  (10, 'Jack Hall', 'jack.hall@example.com')

# %%
# %sql
create or replace function apply_email_rls(email string)
returns string
return case
  when is_account_group_member('masking') then email
  else 'xxxx'
end

# %%
# %sql
select current_user(),is_account_group_member('masking')

# %%
# %sql
select current_user(), is_account_group_member('masking') as is_admin, is_account_group_member('masking') as is_account_admin

# %%
dbutils.fs.ls('abfss://sample@suraj0adls.dfs.core.windows.net/')

# %%
df = spark.sql("""
SELECT 
  id, 
  name, 
  apply_email_rls(email) AS email
FROM sur_pro.default.cust12
""")
display(df)

# %%
# %sql
describe history
